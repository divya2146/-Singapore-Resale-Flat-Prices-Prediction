# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import glob
#house = pd.read_csv("C:\\Users\\User\\Downloads\\resale price document.csv")
house=pd.concat([pd.read_csv(f) for f in glob.glob(r"D:\DS\Capstone projects\New folder\data\*.csv")], ignore_index=True)

# %%
house
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 923656  2014-12      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 923657  2014-12      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 923658  2014-12      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 923659  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 923660  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 923656           122.0        Improved                 1988      580000.0
# 923657           146.0      Maisonette                 1988      540000.0
# 923658           164.0       Apartment                 1992      738000.0
# 923659           152.0      Maisonette                 1985      592000.0
# 923660           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 923656             NaN
# 923657             NaN
# 923658             NaN
# 923659             NaN
# 923660             NaN
#
# [923661 rows x 11 columns]

# %%
# checking dataset shape
house.shape
# Out:
# (923661, 11)

# %%
# checking the datatypes
house.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
# checking the null values in dataset
house.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
# droping remaining_lease missing values
house = house.dropna()
house.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 214611 entries, 656847 to 871457
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                214611 non-null  object
#  1   town                 214611 non-null  object
#  2   flat_type            214611 non-null  object
#  3   block                214611 non-null  object
#  4   street_name          214611 non-null  object
#  5   storey_range         214611 non-null  object
#  6   floor_area_sqm       214611 non-null  float64
#  7   flat_model           214611 non-null  object
#  8   lease_commence_date  214611 non-null  int64
#  9   resale_price         214611 non-null  float64
#  10  remaining_lease      214611 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 19.6+ MB

# %%
#descriptive statistics analaysis

house.describe().T
# Out:
#                         count           mean            std       min  \
# floor_area_sqm       214611.0      97.163595      24.051995      31.0
# lease_commence_date  214611.0    1995.105447      13.654276    1966.0
# resale_price         214611.0  485481.063201  167510.880650  140000.0
#
#                           25%       50%       75%        max
# floor_area_sqm           82.0      94.0     112.0      280.0
# lease_commence_date    1985.0    1995.0    2005.0     2022.0
# resale_price         362000.0  451000.0  575000.0  1568888.0

# %%
# checking the unique values in flat_type feature
house['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              90044
# 5 ROOM              52937
# 3 ROOM              51946
# EXECUTIVE           16051
# 2 ROOM               3470
# MULTI-GENERATION       83
# 1 ROOM                 80
# Name: count, dtype: int64

# %%
# checking the unique values in town feature
house['town'].value_counts()
# Out:
# town
# SENGKANG           17364
# WOODLANDS          15178
# PUNGGOL            14746
# JURONG WEST        14622
# TAMPINES           14516
# YISHUN             14335
# BEDOK              11854
# HOUGANG            10840
# CHOA CHU KANG       9864
# ANG MO KIO          9166
# BUKIT BATOK         8201
# BUKIT MERAH         8184
# BUKIT PANJANG       7958
# TOA PAYOH           6650
# PASIR RIS           6477
# KALLANG/WHAMPOA     6454
# QUEENSTOWN          5879
# SEMBAWANG           5850
# GEYLANG             5376
# CLEMENTI            4934
# JURONG EAST         4466
# SERANGOON           4072
# BISHAN              3918
# CENTRAL AREA        1853
# MARINE PARADE       1318
# BUKIT TIMAH          536
# Name: count, dtype: int64

# %%
house['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    49795
# 07 TO 09    45486
# 10 TO 12    40171
# 01 TO 03    38316
# 13 TO 15    20161
# 16 TO 18     9288
# 19 TO 21     3939
# 22 TO 24     2820
# 25 TO 27     1663
# 28 TO 30     1078
# 31 TO 33      566
# 34 TO 36      520
# 37 TO 39      456
# 40 TO 42      221
# 43 TO 45       64
# 46 TO 48       50
# 49 TO 51       17
# Name: count, dtype: int64

# %%
house['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   72814
# Improved                  53228
# New Generation            28385
# Premium Apartment         23632
# Simplified                 8708
# Apartment                  8041
# Maisonette                 6079
# Standard                   6040
# DBSS                       3195
# Model A2                   2617
# Type S1                     433
# Model A-Maisonette          388
# Adjoined flat               361
# Type S2                     216
# Terrace                     120
# Premium Apartment Loft      108
# 2-room                       90
# Multi Generation             83
# Improved-Maisonette          29
# 3Gen                         28
# Premium Maisonette           16
# Name: count, dtype: int64

# %%
house.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease'],
#       dtype='object')

# %%
# Convert the 'month' column to a datetime format
house['month'] = pd.to_datetime(house['month'])

# Extract the year and month into separate columns
house['year'] = house['month'].dt.year
house['month_of_year'] = house['month'].dt.month
house
# Out:
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\1157337400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['month'] = pd.to_datetime(house['month'])
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\1157337400.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['year'] = house['month'].dt.year
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\1157337400.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['month_of_year'] = house['month'].dt.month
#             month        town  flat_type block        street_name  \
# 656847 2015-01-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4
# 656848 2015-01-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10
# 656849 2015-01-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4
# 656850 2015-01-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10
# 656851 2015-01-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# ...           ...         ...        ...   ...                ...
# 871453 2024-04-01      YISHUN  EXECUTIVE   652       YISHUN AVE 4
# 871454 2024-04-01      YISHUN  EXECUTIVE   392       YISHUN AVE 6
# 871455 2024-04-01      YISHUN  EXECUTIVE   324        YISHUN CTRL
# 871456 2024-04-01      YISHUN  EXECUTIVE   326     YISHUN RING RD
# 871457 2024-04-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 656847     07 TO 09            60.0        Improved                 1986
# 656848     01 TO 03            68.0  New Generation                 1981
# 656849     01 TO 03            69.0  New Generation                 1980
# 656850     01 TO 03            68.0  New Generation                 1979
# 656851     07 TO 09            68.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 871453     07 TO 09           181.0       Apartment                 1992
# 871454     07 TO 09           142.0       Apartment                 1988
# 871455     04 TO 06           146.0       Apartment                 1988
# 871456     04 TO 06           146.0      Maisonette                 1988
# 871457     04 TO 06           146.0      Maisonette                 1988
#
#         resale_price     remaining_lease  year  month_of_year
# 656847      255000.0                  70  2015              1
# 656848      275000.0                  65  2015              1
# 656849      285000.0                  64  2015              1
# 656850      290000.0                  63  2015              1
# 656851      290000.0                  64  2015              1
# ...              ...                 ...   ...            ...
# 871453     1080000.0  67 years 03 months  2024              4
# 871454      780888.0  63 years 03 months  2024              4
# 871455      830000.0  63 years 04 months  2024              4
# 871456      880000.0  63 years 04 months  2024              4
# 871457      900000.0  62 years 10 months  2024              4
#
# [214611 rows x 13 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# dtype: object

# %%
house['lease_commence_year'] = pd.to_datetime(house['lease_commence_date'],format = '%Y').dt.year
# Extract the year of lease commencement
#house['lease_commence_year'] = house['lease_commence_date'].dt.year
# Out:
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\2101682076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['lease_commence_year'] = pd.to_datetime(house['lease_commence_date'],format = '%Y').dt.year

# %%
house
# Out:
#             month        town  flat_type block        street_name  \
# 656847 2015-01-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4
# 656848 2015-01-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10
# 656849 2015-01-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4
# 656850 2015-01-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10
# 656851 2015-01-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# ...           ...         ...        ...   ...                ...
# 871453 2024-04-01      YISHUN  EXECUTIVE   652       YISHUN AVE 4
# 871454 2024-04-01      YISHUN  EXECUTIVE   392       YISHUN AVE 6
# 871455 2024-04-01      YISHUN  EXECUTIVE   324        YISHUN CTRL
# 871456 2024-04-01      YISHUN  EXECUTIVE   326     YISHUN RING RD
# 871457 2024-04-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 656847     07 TO 09            60.0        Improved                 1986
# 656848     01 TO 03            68.0  New Generation                 1981
# 656849     01 TO 03            69.0  New Generation                 1980
# 656850     01 TO 03            68.0  New Generation                 1979
# 656851     07 TO 09            68.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 871453     07 TO 09           181.0       Apartment                 1992
# 871454     07 TO 09           142.0       Apartment                 1988
# 871455     04 TO 06           146.0       Apartment                 1988
# 871456     04 TO 06           146.0      Maisonette                 1988
# 871457     04 TO 06           146.0      Maisonette                 1988
#
#         resale_price     remaining_lease  year  month_of_year  \
# 656847      255000.0                  70  2015              1
# 656848      275000.0                  65  2015              1
# 656849      285000.0                  64  2015              1
# 656850      290000.0                  63  2015              1
# 656851      290000.0                  64  2015              1
# ...              ...                 ...   ...            ...
# 871453     1080000.0  67 years 03 months  2024              4
# 871454      780888.0  63 years 03 months  2024              4
# 871455      830000.0  63 years 04 months  2024              4
# 871456      880000.0  63 years 04 months  2024              4
# 871457      900000.0  62 years 10 months  2024              4
#
#         lease_commence_year
# 656847                 1986
# 656848                 1981
# 656849                 1980
# 656850                 1979
# 656851                 1980
# ...                     ...
# 871453                 1992
# 871454                 1988
# 871455                 1988
# 871456                 1988
# 871457                 1988
#
# [214611 rows x 14 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# lease_commence_year             int32
# dtype: object

# %%
# Extract the remaining_lease feature

data = house['remaining_lease']
house_new = pd.DataFrame(data)

# Extract years and months using regular expressions
lease_info = house['remaining_lease'].str.extract(r'(\d+) years (\d+) months')
lease_info.columns = ['years', 'months']

# Convert to numeric values
house['remaining_lease_years'] = pd.to_numeric(lease_info['years'])
house['remaining_lease_months'] = pd.to_numeric(lease_info['months'])
# Out:
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\3153267670.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['remaining_lease_years'] = pd.to_numeric(lease_info['years'])
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\3153267670.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['remaining_lease_months'] = pd.to_numeric(lease_info['months'])

# %%
house_new_data = house.copy()

# %%
house_new_data
# Out:
#             month        town  flat_type block        street_name  \
# 656847 2015-01-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4
# 656848 2015-01-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10
# 656849 2015-01-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4
# 656850 2015-01-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10
# 656851 2015-01-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# ...           ...         ...        ...   ...                ...
# 871453 2024-04-01      YISHUN  EXECUTIVE   652       YISHUN AVE 4
# 871454 2024-04-01      YISHUN  EXECUTIVE   392       YISHUN AVE 6
# 871455 2024-04-01      YISHUN  EXECUTIVE   324        YISHUN CTRL
# 871456 2024-04-01      YISHUN  EXECUTIVE   326     YISHUN RING RD
# 871457 2024-04-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 656847     07 TO 09            60.0        Improved                 1986
# 656848     01 TO 03            68.0  New Generation                 1981
# 656849     01 TO 03            69.0  New Generation                 1980
# 656850     01 TO 03            68.0  New Generation                 1979
# 656851     07 TO 09            68.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 871453     07 TO 09           181.0       Apartment                 1992
# 871454     07 TO 09           142.0       Apartment                 1988
# 871455     04 TO 06           146.0       Apartment                 1988
# 871456     04 TO 06           146.0      Maisonette                 1988
# 871457     04 TO 06           146.0      Maisonette                 1988
#
#         resale_price     remaining_lease  year  month_of_year  \
# 656847      255000.0                  70  2015              1
# 656848      275000.0                  65  2015              1
# 656849      285000.0                  64  2015              1
# 656850      290000.0                  63  2015              1
# 656851      290000.0                  64  2015              1
# ...              ...                 ...   ...            ...
# 871453     1080000.0  67 years 03 months  2024              4
# 871454      780888.0  63 years 03 months  2024              4
# 871455      830000.0  63 years 04 months  2024              4
# 871456      880000.0  63 years 04 months  2024              4
# 871457      900000.0  62 years 10 months  2024              4
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 656847                 1986                    NaN                     NaN
# 656848                 1981                    NaN                     NaN
# 656849                 1980                    NaN                     NaN
# 656850                 1979                    NaN                     NaN
# 656851                 1980                    NaN                     NaN
# ...                     ...                    ...                     ...
# 871453                 1992                   67.0                     3.0
# 871454                 1988                   63.0                     3.0
# 871455                 1988                   63.0                     4.0
# 871456                 1988                   63.0                     4.0
# 871457                 1988                   62.0                    10.0
#
# [214611 rows x 16 columns]

# %%
house_new_data.isnull().sum()
# Out:
# month                         0
# town                          0
# flat_type                     0
# block                         0
# street_name                   0
# storey_range                  0
# floor_area_sqm                0
# flat_model                    0
# lease_commence_date           0
# resale_price                  0
# remaining_lease               0
# year                          0
# month_of_year                 0
# lease_commence_year           0
# remaining_lease_years     66159
# remaining_lease_months    66159
# dtype: int64

# %%
# handleing the null values using mean method
house_new_data['remaining_lease_years'].fillna(house['remaining_lease_years'].mean(),inplace = True)
house_new_data['remaining_lease_months'].fillna(house['remaining_lease_months'].mean(),inplace = True)
house_new_data.isnull().sum()
# Out:
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\1077114996.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_new_data['remaining_lease_years'].fillna(house['remaining_lease_years'].mean(),inplace = True)
# C:\Users\DIVYA PALAPATI\AppData\Local\Temp\ipykernel_3192\1077114996.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_new_data['remaining_lease_months'].fillna(house['remaining_lease_months'].mean(),inplace = True)
# month                     0
# town                      0
# flat_type                 0
# block                     0
# street_name               0
# storey_range              0
# floor_area_sqm            0
# flat_model                0
# lease_commence_date       0
# resale_price              0
# remaining_lease           0
# year                      0
# month_of_year             0
# lease_commence_year       0
# remaining_lease_years     0
# remaining_lease_months    0
# dtype: int64

# %%
#  dropping the existing features 

house_new_data.drop(columns=['month','lease_commence_date','remaining_lease'],inplace = True)

# %%
house_new_data
# Out:
#               town  flat_type block        street_name storey_range  \
# 656847  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 656848  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 656849  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 656850  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 656851  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# ...            ...        ...   ...                ...          ...
# 871453      YISHUN  EXECUTIVE   652       YISHUN AVE 4     07 TO 09
# 871454      YISHUN  EXECUTIVE   392       YISHUN AVE 6     07 TO 09
# 871455      YISHUN  EXECUTIVE   324        YISHUN CTRL     04 TO 06
# 871456      YISHUN  EXECUTIVE   326     YISHUN RING RD     04 TO 06
# 871457      YISHUN  EXECUTIVE   826       YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  resale_price  year  month_of_year  \
# 656847            60.0        Improved      255000.0  2015              1
# 656848            68.0  New Generation      275000.0  2015              1
# 656849            69.0  New Generation      285000.0  2015              1
# 656850            68.0  New Generation      290000.0  2015              1
# 656851            68.0  New Generation      290000.0  2015              1
# ...                ...             ...           ...   ...            ...
# 871453           181.0       Apartment     1080000.0  2024              4
# 871454           142.0       Apartment      780888.0  2024              4
# 871455           146.0       Apartment      830000.0  2024              4
# 871456           146.0      Maisonette      880000.0  2024              4
# 871457           146.0      Maisonette      900000.0  2024              4
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 656847                 1986              74.076745                6.533472
# 656848                 1981              74.076745                6.533472
# 656849                 1980              74.076745                6.533472
# 656850                 1979              74.076745                6.533472
# 656851                 1980              74.076745                6.533472
# ...                     ...                    ...                     ...
# 871453                 1992              67.000000                3.000000
# 871454                 1988              63.000000                3.000000
# 871455                 1988              63.000000                4.000000
# 871456                 1988              63.000000                4.000000
# 871457                 1988              62.000000               10.000000
#
# [214611 rows x 13 columns]

# %%
#DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
house_new_data['town'] = encoder.fit_transform(house_new_data['town'])
house_new_data['flat_type'] = encoder.fit_transform(house_new_data['flat_type'])
house_new_data['storey_range'] = encoder.fit_transform(house_new_data['storey_range'])
house_new_data['flat_model'] = encoder.fit_transform(house_new_data['flat_model'])

# %%
house_new_data
# Out:
#         town  flat_type block        street_name  storey_range  \
# 656847     0          2   174   ANG MO KIO AVE 4             2
# 656848     0          2   541  ANG MO KIO AVE 10             0
# 656849     0          2   163   ANG MO KIO AVE 4             0
# 656850     0          2   446  ANG MO KIO AVE 10             0
# 656851     0          2   557  ANG MO KIO AVE 10             2
# ...      ...        ...   ...                ...           ...
# 871453    25          5   652       YISHUN AVE 4             2
# 871454    25          5   392       YISHUN AVE 6             2
# 871455    25          5   324        YISHUN CTRL             1
# 871456    25          5   326     YISHUN RING RD             1
# 871457    25          5   826       YISHUN ST 81             1
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 656847            60.0           5      255000.0  2015              1
# 656848            68.0          12      275000.0  2015              1
# 656849            69.0          12      285000.0  2015              1
# 656850            68.0          12      290000.0  2015              1
# 656851            68.0          12      290000.0  2015              1
# ...                ...         ...           ...   ...            ...
# 871453           181.0           3     1080000.0  2024              4
# 871454           142.0           3      780888.0  2024              4
# 871455           146.0           3      830000.0  2024              4
# 871456           146.0           7      880000.0  2024              4
# 871457           146.0           7      900000.0  2024              4
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 656847                 1986              74.076745                6.533472
# 656848                 1981              74.076745                6.533472
# 656849                 1980              74.076745                6.533472
# 656850                 1979              74.076745                6.533472
# 656851                 1980              74.076745                6.533472
# ...                     ...                    ...                     ...
# 871453                 1992              67.000000                3.000000
# 871454                 1988              63.000000                3.000000
# 871455                 1988              63.000000                4.000000
# 871456                 1988              63.000000                4.000000
# 871457                 1988              62.000000               10.000000
#
# [214611 rows x 13 columns]

# %%
# after encoding descriptive statistics analaysis

house_new_data.describe().T
# Out:
#                            count           mean            std       min  \
# town                    214611.0      13.895630       7.955173       0.0
# flat_type               214611.0       3.121904       0.918984       0.0
# storey_range            214611.0       2.219770       1.948737       0.0
# floor_area_sqm          214611.0      97.163595      24.051995      31.0
# flat_model              214611.0       8.694382       3.648841       0.0
# resale_price            214611.0  485481.063201  167510.880650  140000.0
# year                    214611.0    2019.533044       2.644904    2015.0
# month_of_year           214611.0       6.525495       3.426609       1.0
# lease_commence_year     214611.0    1995.105447      13.654276    1966.0
# remaining_lease_years   214611.0      74.076745      11.556887      41.0
# remaining_lease_months  214611.0       6.533472       2.401043       0.0
#
#                              25%            50%       75%        max
# town                         8.0      14.000000      21.0       25.0
# flat_type                    2.0       3.000000       4.0        6.0
# storey_range                 1.0       2.000000       3.0       16.0
# floor_area_sqm              82.0      94.000000     112.0      280.0
# flat_model                   5.0       8.000000      12.0       20.0
# resale_price            362000.0  451000.000000  575000.0  1568888.0
# year                      2017.0    2020.000000    2022.0     2024.0
# month_of_year                4.0       7.000000       9.0       12.0
# lease_commence_year       1985.0    1995.000000    2005.0     2022.0
# remaining_lease_years       66.0      74.076745      80.0       97.0
# remaining_lease_months       5.0       6.533472       8.0       11.0

# %%
#Skewness Handling

# %%
# checking the outliars using boxplot distribution plot

def plot(house_new_data,column):
    plt.figure(figsize =(15,6))
    plt.subplot(1,3,1)
    sns.boxplot(data = house_new_data ,x = column)
    plt.title(f'box plot for {column}')
    

    plt.subplot(1,3,2)
    sns.histplot(data = house_new_data ,x = column,kde = True ,bins = 40)
    plt.title(f'distribution  plot for {column}')
    plt.show()

# %%
for i in ['floor_area_sqm','resale_price','lease_commence_year','remaining_lease_years']:
    plot(house_new_data ,i)

# %%
# 'floor_area_sqm','resale_price' this two feature are skewd in data handling log method 


house_new_data['floor_area_sqm'] = np.log(house_new_data['floor_area_sqm'])
house_new_data['resale_price'] = np.log(house_new_data['resale_price'])
house_new_data
# Out:
#         town  flat_type block        street_name  storey_range  \
# 656847     0          2   174   ANG MO KIO AVE 4             2
# 656848     0          2   541  ANG MO KIO AVE 10             0
# 656849     0          2   163   ANG MO KIO AVE 4             0
# 656850     0          2   446  ANG MO KIO AVE 10             0
# 656851     0          2   557  ANG MO KIO AVE 10             2
# ...      ...        ...   ...                ...           ...
# 871453    25          5   652       YISHUN AVE 4             2
# 871454    25          5   392       YISHUN AVE 6             2
# 871455    25          5   324        YISHUN CTRL             1
# 871456    25          5   326     YISHUN RING RD             1
# 871457    25          5   826       YISHUN ST 81             1
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 656847        4.094345           5     12.449019  2015              1
# 656848        4.219508          12     12.524526  2015              1
# 656849        4.234107          12     12.560244  2015              1
# 656850        4.219508          12     12.577636  2015              1
# 656851        4.219508          12     12.577636  2015              1
# ...                ...         ...           ...   ...            ...
# 871453        5.198497           3     13.892472  2024              4
# 871454        4.955827           3     13.568187  2024              4
# 871455        4.983607           3     13.629181  2024              4
# 871456        4.983607           7     13.687677  2024              4
# 871457        4.983607           7     13.710150  2024              4
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 656847                 1986              74.076745                6.533472
# 656848                 1981              74.076745                6.533472
# 656849                 1980              74.076745                6.533472
# 656850                 1979              74.076745                6.533472
# 656851                 1980              74.076745                6.533472
# ...                     ...                    ...                     ...
# 871453                 1992              67.000000                3.000000
# 871454                 1988              63.000000                3.000000
# 871455                 1988              63.000000                4.000000
# 871456                 1988              63.000000                4.000000
# 871457                 1988              62.000000               10.000000
#
# [214611 rows x 13 columns]

# %%
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data,i)

# %%
#Treat Outliers using IQR

# %%
#using the IQR & Clips  method removing the outliars :
# formula IQR = Q3_Q1
def outlier(house_new_data ,column):
    IQR = house_new_data[column].quantile(0.75)-house_new_data[column].quantile(0.25)
    upper_value = house_new_data[column].quantile(0.75)+1.5*IQR
    lower_value = house_new_data[column].quantile(0.25)-1.5*IQR
    
    house_new_data[column] =     house_new_data[column].clip(upper_value,lower_value)

outlier(house_new_data, 'floor_area_sqm')
outlier(house_new_data, 'resale_price')
house_new_data1 = house_new_data.copy()

# %%
house_new_data1
# Out:
#         town  flat_type block        street_name  storey_range  \
# 656847     0          2   174   ANG MO KIO AVE 4             2
# 656848     0          2   541  ANG MO KIO AVE 10             0
# 656849     0          2   163   ANG MO KIO AVE 4             0
# 656850     0          2   446  ANG MO KIO AVE 10             0
# 656851     0          2   557  ANG MO KIO AVE 10             2
# ...      ...        ...   ...                ...           ...
# 871453    25          5   652       YISHUN AVE 4             2
# 871454    25          5   392       YISHUN AVE 6             2
# 871455    25          5   324        YISHUN CTRL             1
# 871456    25          5   326     YISHUN RING RD             1
# 871457    25          5   826       YISHUN ST 81             1
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 656847        4.094345           5     12.449019  2015              1
# 656848        4.219508          12     12.524526  2015              1
# 656849        4.234107          12     12.560244  2015              1
# 656850        4.219508          12     12.577636  2015              1
# 656851        4.219508          12     12.577636  2015              1
# ...                ...         ...           ...   ...            ...
# 871453        5.186168           3     13.892472  2024              4
# 871454        4.955827           3     13.568187  2024              4
# 871455        4.983607           3     13.629181  2024              4
# 871456        4.983607           7     13.687677  2024              4
# 871457        4.983607           7     13.710150  2024              4
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 656847                 1986              74.076745                6.533472
# 656848                 1981              74.076745                6.533472
# 656849                 1980              74.076745                6.533472
# 656850                 1979              74.076745                6.533472
# 656851                 1980              74.076745                6.533472
# ...                     ...                    ...                     ...
# 871453                 1992              67.000000                3.000000
# 871454                 1988              63.000000                3.000000
# 871455                 1988              63.000000                4.000000
# 871456                 1988              63.000000                4.000000
# 871457                 1988              62.000000               10.000000
#
# [214611 rows x 13 columns]

# %%
# after IQR using checking the skewness
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data1,i)

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_model', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_model'>

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'town', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='town'>

# %%
#Basic EDA

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_type', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_type'>

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'resale_price' ,y = 'floor_area_sqm',data = house)
# Out:
# <Axes: xlabel='resale_price', ylabel='floor_area_sqm'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'lease_commence_year' , y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='lease_commence_year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'year', y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'remaining_lease_years' , y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='remaining_lease_years', ylabel='resale_price'>

# %%
# dropping the irrelvent feature 
house_new_data1.drop(columns=['block','street_name'],inplace = True)
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 656847     0          2             2        4.094345           5
# 656848     0          2             0        4.219508          12
# 656849     0          2             0        4.234107          12
# 656850     0          2             0        4.219508          12
# 656851     0          2             2        4.219508          12
# ...      ...        ...           ...             ...         ...
# 871453    25          5             2        5.186168           3
# 871454    25          5             2        4.955827           3
# 871455    25          5             1        4.983607           3
# 871456    25          5             1        4.983607           7
# 871457    25          5             1        4.983607           7
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 656847     12.449019  2015              1                 1986
# 656848     12.524526  2015              1                 1981
# 656849     12.560244  2015              1                 1980
# 656850     12.577636  2015              1                 1979
# 656851     12.577636  2015              1                 1980
# ...              ...   ...            ...                  ...
# 871453     13.892472  2024              4                 1992
# 871454     13.568187  2024              4                 1988
# 871455     13.629181  2024              4                 1988
# 871456     13.687677  2024              4                 1988
# 871457     13.710150  2024              4                 1988
#
#         remaining_lease_years  remaining_lease_months
# 656847              74.076745                6.533472
# 656848              74.076745                6.533472
# 656849              74.076745                6.533472
# 656850              74.076745                6.533472
# 656851              74.076745                6.533472
# ...                       ...                     ...
# 871453              67.000000                3.000000
# 871454              63.000000                3.000000
# 871455              63.000000                4.000000
# 871456              63.000000                4.000000
# 871457              62.000000               10.000000
#
# [214611 rows x 11 columns]

# %%
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 656847     0          2             2        4.094345           5
# 656848     0          2             0        4.219508          12
# 656849     0          2             0        4.234107          12
# 656850     0          2             0        4.219508          12
# 656851     0          2             2        4.219508          12
# ...      ...        ...           ...             ...         ...
# 871453    25          5             2        5.186168           3
# 871454    25          5             2        4.955827           3
# 871455    25          5             1        4.983607           3
# 871456    25          5             1        4.983607           7
# 871457    25          5             1        4.983607           7
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 656847     12.449019  2015              1                 1986
# 656848     12.524526  2015              1                 1981
# 656849     12.560244  2015              1                 1980
# 656850     12.577636  2015              1                 1979
# 656851     12.577636  2015              1                 1980
# ...              ...   ...            ...                  ...
# 871453     13.892472  2024              4                 1992
# 871454     13.568187  2024              4                 1988
# 871455     13.629181  2024              4                 1988
# 871456     13.687677  2024              4                 1988
# 871457     13.710150  2024              4                 1988
#
#         remaining_lease_years  remaining_lease_months
# 656847              74.076745                6.533472
# 656848              74.076745                6.533472
# 656849              74.076745                6.533472
# 656850              74.076745                6.533472
# 656851              74.076745                6.533472
# ...                       ...                     ...
# 871453              67.000000                3.000000
# 871454              63.000000                3.000000
# 871455              63.000000                4.000000
# 871456              63.000000                4.000000
# 871457              62.000000               10.000000
#
# [214611 rows x 11 columns]

# %%
house_new_data1.dtypes
# Out:
# town                        int32
# flat_type                   int32
# storey_range                int32
# floor_area_sqm            float64
# flat_model                  int32
# resale_price              float64
# year                        int32
# month_of_year               int32
# lease_commence_year         int32
# remaining_lease_years     float64
# remaining_lease_months    float64
# dtype: object

# %%
heat = house_new_data1.corr()
heat
# Out:
#                             town  flat_type  storey_range  floor_area_sqm  \
# town                    1.000000   0.110594     -0.052633        0.107233
# flat_type               0.110594   1.000000      0.040070        0.945144
# storey_range           -0.052633   0.040070      1.000000        0.011537
# floor_area_sqm          0.107233   0.945144      0.011537        1.000000
# flat_model             -0.091192  -0.330378     -0.040135       -0.330182
# resale_price           -0.012360   0.661567      0.332167        0.662054
# year                    0.028168  -0.009462      0.037456       -0.016652
# month_of_year           0.005990   0.006530     -0.002332        0.003906
# lease_commence_year     0.218211   0.216136      0.275466        0.197257
# remaining_lease_years   0.178059   0.155948      0.232967        0.138680
# remaining_lease_months  0.005997  -0.001477     -0.001980       -0.002360
#
#                         flat_model  resale_price      year  month_of_year  \
# town                     -0.091192     -0.012360  0.028168       0.005990
# flat_type                -0.330378      0.661567 -0.009462       0.006530
# storey_range             -0.040135      0.332167  0.037456      -0.002332
# floor_area_sqm           -0.330182      0.662054 -0.016652       0.003906
# flat_model                1.000000     -0.247723 -0.030199      -0.004901
# resale_price             -0.247723      1.000000  0.302419      -0.011142
# year                     -0.030199      0.302419  1.000000      -0.102017
# month_of_year            -0.004901     -0.011142 -0.102017       1.000000
# lease_commence_year      -0.127896      0.417465  0.187049       0.001917
# remaining_lease_years    -0.102570      0.305986 -0.008689      -0.008404
# remaining_lease_months    0.000956      0.003990  0.004880       0.015651
#
#                         lease_commence_year  remaining_lease_years  \
# town                               0.218211               0.178059
# flat_type                          0.216136               0.155948
# storey_range                       0.275466               0.232967
# floor_area_sqm                     0.197257               0.138680
# flat_model                        -0.127896              -0.102570
# resale_price                       0.417465               0.305986
# year                               0.187049              -0.008689
# month_of_year                      0.001917              -0.008404
# lease_commence_year                1.000000               0.842210
# remaining_lease_years              0.842210               1.000000
# remaining_lease_months             0.013603              -0.002857
#
#                         remaining_lease_months
# town                                  0.005997
# flat_type                            -0.001477
# storey_range                         -0.001980
# floor_area_sqm                       -0.002360
# flat_model                            0.000956
# resale_price                          0.003990
# year                                  0.004880
# month_of_year                         0.015651
# lease_commence_year                   0.013603
# remaining_lease_years                -0.002857
# remaining_lease_months                1.000000

# %%
# Need to verify any columns are highly correlated using Heatmap
plt.figure(figsize=(15,6))
sns.heatmap(heat,annot = True)
# Out:
# <Axes: >

# %%
#Model Buliding:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model   import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import pickle

# %%
house_new_data1.columns
# Out:
# Index(['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'year', 'month_of_year', 'lease_commence_year',
#        'remaining_lease_years', 'remaining_lease_months'],
#       dtype='object')

# %%
x = house_new_data1[['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
        'year', 'month_of_year', 'lease_commence_year',
       'remaining_lease_years', 'remaining_lease_months']]
y = house_new_data1[['resale_price']]

# %%
#standardize the features of a dataset
encoder = StandardScaler()

encoder.fit_transform(x)
# Out:
# array([[-1.74674537e+00, -1.22081284e+00, -1.12775743e-01, ...,
#         -6.66858342e-01,  0.00000000e+00,  3.69914382e-16],
#        [-1.74674537e+00, -1.22081284e+00, -1.13908402e+00, ...,
#         -1.03304485e+00,  0.00000000e+00,  3.69914382e-16],
#        [-1.74674537e+00, -1.22081284e+00, -1.13908402e+00, ...,
#         -1.10628215e+00,  0.00000000e+00,  3.69914382e-16],
#        ...,
#        [ 1.39587104e+00,  2.04367111e+00, -6.25929880e-01, ...,
#         -5.20383738e-01, -9.58456305e-01, -1.05515710e+00],
#        [ 1.39587104e+00,  2.04367111e+00, -6.25929880e-01, ...,
#         -5.20383738e-01, -9.58456305e-01, -1.05515710e+00],
#        [ 1.39587104e+00,  2.04367111e+00, -6.25929880e-01, ...,
#         -5.20383738e-01, -1.04498500e+00,  1.44376231e+00]])

# %%
#check the accuracy of training and testing using metrics RandomForestRegressor


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

RFR= RandomForestRegressor(n_estimators= 50 ,random_state = 0)

# fitting the model: 

RFR.fit(x_train,y_train)

y_pred_train = RFR.predict(x_train)
y_pred_test = RFR.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9927076877265862, 0.9535844807288163)

# %%
# we got good accuracy after oversampling
# RandomForestRegressor have good testing accuracy, but in training accuracy is overfitting.

# %%
# GridsearchCV is a cross validation function
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

param = {'max_depth'        : [20],
              'min_samples_split': [ 5, ],
              'min_samples_leaf' : [ 2, ],
              'max_features'     : ['log2']}
grid_searchcv = GridSearchCV(RandomForestRegressor(),param_grid = param,  cv = 5)
grid_searchcv.fit(x_train, y_train)
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20], 'max_features': ['log2'],
#                          'min_samples_leaf': [2], 'min_samples_split': [5]})

# %%
grid_searchcv.best_score_
# Out:
# 0.9291297083512713

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.956875034397499, 0.9301855960155672)

# %%
# now the training accuracy overfitting reduced. so now model will predict effectively for unseen data

# %%
# predict the selling price with hypertuning parameters and calculate the accuracy using metrics

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)                      
print('Mean Squared Error:' ,mean_squared_error(y_test,y_pred_test))
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred_test)))
print(r2_score(y_test,y_pred_test))
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error: 0.007732305242192312
# Mean Absolute Error: 0.0635632368337804
# Root Mean Squared Error: 0.08793352740674237
# 0.9288799621856638

# %%
# manually passed the user input and predict the selling price

user_data = np.array([[0,1,3,3.785069,5,2017,1,1979,61.000000,4.000000]])
y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 12.376178613406132

# %%
user_data = np.array([[4,3,2,4.785069,4,2023,3,1989,69.000000,4.000000]])

y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 13.52893348652331

# %%
# using Inverse Log Transformation to convert the value to original re sale price of the data (exp)
np.exp(y_prediction[0])
# Out:
# 750829.2088120271

# %%
# save the regression model by using pickle
#"D:\DS\Capstone projects\New folder\data"
import pickle

with open(r"D:\DS\Capstone projects\New folder\data\\house_price_model.pkl", 'wb') as f:
    pickle.dump(Hyper_model, f)

# %%
# load the model
import pickle
with open(r"D:\DS\Capstone projects\New folder\data\\house_price_model.pkl", 'rb') as f:
    model = pickle.load(f)

user_data = np.array([[4, 3, 2, 4.785069, 4, 2023, 3, 1989, 69.000000, 4.000000]])
prediction = model.predict(user_data)
predicted_price = prediction[0]
predicted_price
np.exp(predicted_price)
# Out:
# c:\Users\DIVYA PALAPATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 750829.2088120271
